# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import friedmanchisquare
from scikit_posthocs import posthoc_nemenyi_friedman as nemenyi

# %%
df = pd.read_csv("/home/dobraczka/Downloads/git/er-embedding-benchmark/data/all_results.csv",header=0,sep=",")

# %% [markdown]
# # Analysis of Feature Input (for MultiKE)
# To check if using embeddings in conjunction with similarities provides an improvement overall we sum the test_f1 value over all folds and classifiers

# %%
df["dataset"] = df["dataset"].str.replace(r"-721_5fold-\d","")
#aggregated = df.groupby(["dataset","embed_model","vector_name","model_name"]).mean()
aggregated = df.groupby(["embed_model","vector_name","dataset"]).mean()

# %%
#one_data_series = aggregated.loc[("D_W_15K_V1","MultiKE")]["test_f1"]
one_data_series = aggregated.loc[("MultiKE")]["test_f1"]
one_data_block_design = pd.DataFrame([one_data_series['OnlyEmb'], one_data_series['OnlySim'], one_data_series['OnlySimNormalized'], one_data_series['SimAndEmb'], one_data_series['SimAndEmbNormalized']]).T
one_data_block_design.columns = ['OnlyEmb','OnlySim','OnlySimNormalized','SimAndEmb','SimAndEmbNormalized']

# %%
cm = sns.cubehelix_palette(5, as_cmap=True)
s = one_data_block_design.style.background_gradient(cmap=cm, axis=1)
s
# Out:
# <style  type="text/css" >
#     #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col0 {
#             background-color:  #bf7c99;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col1 {
#             background-color:  #b57294;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col3 {
#             background-color:  #3b264b;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col4 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col0 {
#             background-color:  #ce8fa2;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col1 {
#             background-color:  #9a5b88;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col3 {
#             background-color:  #482c57;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col4 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col1 {
#             background-color:  #2e1f3f;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col2 {
#             background-color:  #533260;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col3 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col4 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow3_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow3_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow3_col2 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow3_col3 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow3_col4 {
#             background-color:  #3d274e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow4_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow4_col1 {
#             background-color:  #daa4ac;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow4_col2 {
#             background-color:  #d59ba8;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow4_col3 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow4_col4 {
#             background-color:  #834c7d;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow5_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow5_col1 {
#             background-color:  #9f5f8a;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow5_col2 {
#             background-color:  #cf91a3;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow5_col3 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow5_col4 {
#             background-color:  #814a7c;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow6_col0 {
#             background-color:  #e1b1b4;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow6_col1 {
#             background-color:  #aa688f;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow6_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow6_col3 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow6_col4 {
#             background-color:  #3c264d;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow7_col0 {
#             background-color:  #c07d99;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow7_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow7_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow7_col3 {
#             background-color:  #2e1f3f;
#             color:  #f1f1f1;
#         }    #T_2031497e_bfc7_11ea_80cf_94e6f707a57brow7_col4 {
#             background-color:  #62396a;
#             color:  #f1f1f1;
#         }</style><table id="T_2031497e_bfc7_11ea_80cf_94e6f707a57b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >OnlyEmb</th>        <th class="col_heading level0 col1" >OnlySim</th>        <th class="col_heading level0 col2" >OnlySimNormalized</th>        <th class="col_heading level0 col3" >SimAndEmb</th>        <th class="col_heading level0 col4" >SimAndEmbNormalized</th>    </tr>    <tr>        <th class="index_name level0" >dataset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2031497e_bfc7_11ea_80cf_94e6f707a57blevel0_row0" class="row_heading level0 row0" >D_W_15K_V1</th>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col0" class="data row0 col0" >0.785645</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col1" class="data row0 col1" >0.790195</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col2" class="data row0 col2" >0.748303</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col3" class="data row0 col3" >0.83849</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow0_col4" class="data row0 col4" >0.843858</td>
#             </tr>
#             <tr>
#                         <th id="T_2031497e_bfc7_11ea_80cf_94e6f707a57blevel0_row1" class="row_heading level0 row1" >D_W_15K_V2</th>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col0" class="data row1 col0" >0.85083</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col1" class="data row1 col1" >0.872561</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col2" class="data row1 col2" >0.826816</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col3" class="data row1 col3" >0.8989</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow1_col4" class="data row1 col4" >0.907431</td>
#             </tr>
#             <tr>
#                         <th id="T_2031497e_bfc7_11ea_80cf_94e6f707a57blevel0_row2" class="row_heading level0 row2" >D_Y_15K_V1</th>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col0" class="data row2 col0" >0.862925</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a57brow2_col1" class="data row2 col1" >0.985768</td>
#                         <td id="T_2031497e_bfc7_11ea_80cf_94e6f707a

# %% [markdown]
# Using Embeddings seems to improve the results.
# Let's test if the difference is significant!

# %% [markdown]
# The Friedman test is designed to check if there is a significant difference in the rank sums

# %%
statistic, pvalue = friedmanchisquare(one_data_series['OnlyEmb'], one_data_series['OnlySim'], one_data_series['OnlySimNormalized'], one_data_series['SimAndEmb'], one_data_series['SimAndEmbNormalized'])
if pvalue < 0.05:
    print("There is a significant difference in the rank sums: ", pvalue)
    res = nemenyi(one_data_block_design)
res
# Out:
# There is a significant difference in the rank sums:  6.053820135900641e-05
#                       OnlyEmb   OnlySim  OnlySimNormalized  SimAndEmb  \
# OnlyEmb             -1.000000  0.123326           0.900000   0.001000
# OnlySim              0.123326 -1.000000           0.174719   0.508007
# OnlySimNormalized    0.900000  0.174719          -1.000000   0.001393
# SimAndEmb            0.001000  0.508007           0.001393  -1.000000
# SimAndEmbNormalized  0.022374  0.900000           0.035854   0.866947
#
#                      SimAndEmbNormalized
# OnlyEmb                         0.022374
# OnlySim                         0.900000
# OnlySimNormalized               0.035854
# SimAndEmb                       0.866947
# SimAndEmbNormalized            -1.000000

# %% [markdown]
# There is a significant difference (p < 0.05) between using OnlyEmb and SimAndEmb/SimAndEmbNormalized.
#
# There is also a significant difference (p < 0.05) between using OnlySim and SimAndEmb/SimAndEmbNormalized.
#
# # Using similarities in conjunction with embeddings results in significant improvements for all classifiers, than using either similarities or embeddings on their own
