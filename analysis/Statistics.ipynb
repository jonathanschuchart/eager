# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import friedmanchisquare
from scikit_posthocs import posthoc_nemenyi_friedman as nemenyi

# %%
df = pd.read_csv("/home/dobraczka/Downloads/git/er-embedding-benchmark/data/all_results.csv",header=0,sep=",")
df["dataset"] = df["dataset"].str.replace(r"-721_5fold-\d","")

# %%
# creates a df with mean value of folds and all values per feature variant with all classifiers and datasets as rows
def get_expanded_df(df, removed_dim_name, fixed_value, levels):
    aggregated = df[df[removed_dim_name]==fixed_value].groupby(levels).mean()
    #level_zero = df["model_name"].unique()
    #level_one = df["vector_name"].unique()
    level_zero = df[levels[0]].unique()
    level_one = df[levels[1]].unique()
    variant_cols = []
    row_names = None
    for f in level_one:
        tmp_names = None
        tmp_col = None
        for m in level_zero:
            tmp = aggregated.loc[(m,f)]["test_f1"]
            tmp = tmp.add_suffix("_" + m)
            tmp.name = f
            if tmp_names is None:
                tmp_names = set(tmp.index.to_list())
            else:
                tmp_names = tmp_names | set(tmp.index.to_list())
            if tmp_col is None:
                tmp_col = tmp
            else:
                tmp_col = tmp_col.append(tmp)
        if row_names is None:
            row_names = tmp_names
        else:
            row_names = row_names & tmp_names
        variant_cols.append(tmp_col)
    for i in range(0, len(variant_cols)):
        variant_cols[i] = variant_cols[i].loc[row_names]
    expanded = pd.DataFrame(variant_cols).T
    expanded.sort_index(inplace=True)
    return expanded

# %%
def stylize(df):
    cm = sns.cubehelix_palette(5, as_cmap=True)
    return df.style.background_gradient(cmap=cm, axis=1)

# %%
def statistical_test(df, features=True):
    #dont know how to better provide the arguments without it being interpreted as single array
    if features:
        statistic, pvalue = friedmanchisquare(df['OnlyEmb'], df['OnlySim'], df['OnlySimNormalized'], df['SimAndEmb'], df['SimAndEmbNormalized'])
    else:
        statistic, pvalue = friedmanchisquare(df.iloc[0],df.iloc[1],df.iloc[2],df.iloc[3],df.iloc[4],df.iloc[5],df.iloc[6],df.iloc[7])
    if pvalue < 0.05:
        print("There is a significant difference in the rank sums: ", pvalue)
        res = nemenyi(df)
        return res
    else:
        print("No significant difference")
        return None

# %% [markdown]
# # Analysis of Feature Input for RDGCN
# To check if using embeddings in conjunction with similarities provides an improvement overall we sum the test_f1 value over all folds

# %%
whole_df = get_expanded_df(df,"embed_model","RDGCN",["model_name","vector_name","dataset"])
stylized = stylize(whole_df)
stylized
# Out:
# <style  type="text/css" >
#     #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow0_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow0_col1 {
#             background-color:  #834c7d;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow0_col2 {
#             background-color:  #a9678f;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow0_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow0_col4 {
#             background-color:  #edd0ca;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow1_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow1_col1 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow1_col2 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow1_col3 {
#             background-color:  #4d2f5b;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow1_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow2_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow2_col1 {
#             background-color:  #342245;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow2_col2 {
#             background-color:  #422952;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow2_col3 {
#             background-color:  #322143;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow2_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow3_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow3_col1 {
#             background-color:  #a8668e;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow3_col2 {
#             background-color:  #643a6b;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow3_col3 {
#             background-color:  #a9678f;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow3_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow4_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow4_col1 {
#             background-color:  #6f4172;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow4_col2 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow4_col3 {
#             background-color:  #6c3f70;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow4_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow5_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow5_col1 {
#             background-color:  #b97596;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow5_col2 {
#             background-color:  #693d6f;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow5_col3 {
#             background-color:  #b77495;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow5_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow6_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow6_col1 {
#             background-color:  #905483;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow6_col2 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow6_col3 {
#             background-color:  #8d5282;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow6_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow7_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow7_col1 {
#             background-color:  #c2809b;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow7_col2 {
#             background-color:  #774576;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow7_col3 {
#             background-color:  #c07d99;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow7_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow8_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow8_col1 {
#             background-color:  #6e4071;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow8_col2 {
#             background-color:  #dca7ae;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow8_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow8_col4 {
#             background-color:  #7c4879;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow9_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow9_col1 {
#             background-color:  #613969;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow9_col2 {
#             background-color:  #a5648d;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow9_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow9_col4 {
#             background-color:  #e0b0b3;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow10_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow10_col1 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow10_col2 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow10_col3 {
#             background-color:  #593564;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow10_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow11_col0 {
#             background-color:  #7e497a;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow11_col1 {
#             background-color:  #784577;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow11_col2 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow11_col3 {
#             background-color:  #834c7d;
#             color:  #f1f1f1;
#         }    #T_fba30ef4_c060_11ea_bb4e_98fa9be288bbrow11_col4 {
#             background-color:  #edd1cb;
#             color:  #0

# %% [markdown]
# Mean row wise rank (the lower the better):

# %%
whole_df.apply(lambda x: x.rank(ascending=False), axis=1).mean().sort_values()
# Out:
# SimAndEmb              1.717949
# OnlySim                1.995726
# SimAndEmbNormalized    3.179487
# OnlySimNormalized      3.534188
# OnlyEmb                4.572650
# dtype: float64

# %% [markdown]
# Using embeddings AND similarity seems to improve the results slightly.
# Let's test if the difference is significant!

# %% [markdown]
# The Friedman test is designed to check if there is a significant difference in the rank sums

# %%
res = statistical_test(whole_df)
res
# Out:
# There is a significant difference in the rank sums:  3.616224127070425e-54
#                      SimAndEmb  SimAndEmbNormalized   OnlySim  \
# SimAndEmb            -1.000000             0.001000  0.642759
# SimAndEmbNormalized   0.001000            -1.000000  0.001000
# OnlySim               0.642759             0.001000 -1.000000
# OnlySimNormalized     0.001000             0.425813  0.001000
# OnlyEmb               0.001000             0.001000  0.001000
#
#                      OnlySimNormalized  OnlyEmb
# SimAndEmb                     0.001000    0.001
# SimAndEmbNormalized           0.425813    0.001
# OnlySim                       0.001000    0.001
# OnlySimNormalized            -1.000000    0.001
# OnlyEmb                       0.001000   -1.000

# %% [markdown]
# Values below 0.05 show a significant difference. So keeping the mean row wise ranks in mind:
# SimAndEmb is significantly better than SimAndEmbNormalized, OnlySimNormalized and OnlyEmb

# %% [markdown]
# # Analysis of Feature Input for MultiKE
# To check if using embeddings in conjunction with similarities provides an improvement overall we sum the test_f1 value over all folds

# %%
whole_df = get_expanded_df(df,"embed_model","MultiKE",["model_name","vector_name","dataset"])
stylized = stylize(whole_df)
stylized
# Out:
# <style  type="text/css" >
#     #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow0_col0 {
#             background-color:  #52315f;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow0_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow0_col2 {
#             background-color:  #c3819c;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow0_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow0_col4 {
#             background-color:  #884f7f;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow1_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow1_col1 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow1_col2 {
#             background-color:  #422952;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow1_col3 {
#             background-color:  #794678;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow1_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow2_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow2_col1 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow2_col2 {
#             background-color:  #884f7f;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow2_col3 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow2_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow3_col0 {
#             background-color:  #553361;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow3_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow3_col2 {
#             background-color:  #834c7d;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow3_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow3_col4 {
#             background-color:  #6f4172;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow4_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow4_col1 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow4_col2 {
#             background-color:  #683d6e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow4_col3 {
#             background-color:  #ebcac5;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow4_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow5_col0 {
#             background-color:  #62396a;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow5_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow5_col2 {
#             background-color:  #8d5282;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow5_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow5_col4 {
#             background-color:  #583463;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow6_col0 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow6_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow6_col2 {
#             background-color:  #754475;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow6_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow6_col4 {
#             background-color:  #985987;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow7_col0 {
#             background-color:  #5f3868;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow7_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow7_col2 {
#             background-color:  #8d5282;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow7_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow7_col4 {
#             background-color:  #432a53;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow8_col0 {
#             background-color:  #3b264b;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow8_col1 {
#             background-color:  #452b54;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow8_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow8_col3 {
#             background-color:  #e6bdbc;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow8_col4 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow9_col0 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow9_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow9_col2 {
#             background-color:  #7c4879;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow9_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow9_col4 {
#             background-color:  #7b4779;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow10_col0 {
#             background-color:  #50305d;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow10_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow10_col2 {
#             background-color:  #362347;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow10_col3 {
#             background-color:  #613969;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow10_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow11_col0 {
#             background-color:  #6e4071;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow11_col1 {
#             background-color:  #6c3f70;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow11_col2 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow11_col3 {
#             background-color:  #6c3f70;
#             color:  #f1f1f1;
#         }    #T_fbe49c34_c060_11ea_bb4e_98fa9be288bbrow11_col4 {
#             background-color:  #edd1cb;
#             color:  #0

# %% [markdown]
# Mean row wise rank (the lower the better):

# %%
whole_df.apply(lambda x: x.rank(ascending=False), axis=1).mean().sort_values()
# Out:
# SimAndEmb              1.777778
# OnlySim                2.347222
# SimAndEmbNormalized    2.527778
# OnlyEmb                4.027778
# OnlySimNormalized      4.319444
# dtype: float64

# %% [markdown]
# Using embeddings AND similarities seems to improve the results.
# Let's test if the difference is significant!

# %% [markdown]
# The Friedman test is designed to check if there is a significant difference in the rank sums

# %%
res = statistical_test(whole_df)
res
# Out:
# There is a significant difference in the rank sums:  9.182111362836687e-30
#                      SimAndEmb  SimAndEmbNormalized   OnlySim  \
# SimAndEmb            -1.000000             0.035854  0.194648
# SimAndEmbNormalized   0.035854            -1.000000  0.900000
# OnlySim               0.194648             0.900000 -1.000000
# OnlySimNormalized     0.001000             0.001000  0.001000
# OnlyEmb               0.001000             0.001000  0.001000
#
#                      OnlySimNormalized   OnlyEmb
# SimAndEmb                     0.001000  0.001000
# SimAndEmbNormalized           0.001000  0.001000
# OnlySim                       0.001000  0.001000
# OnlySimNormalized            -1.000000  0.777213
# OnlyEmb                       0.777213 -1.000000

# %% [markdown]
# The advantage of SimAndEmb is more clear here, which is probably due to the missing CSV and Movie datasets

# %% [markdown]
# # Analysis of Feature Input for BootEA
# To check if using embeddings in conjunction with similarities provides an improvement overall we sum the test_f1 value over all folds

# %%
whole_df = get_expanded_df(df,"embed_model","BootEA",["model_name","vector_name","dataset"])
cm = sns.cubehelix_palette(5, as_cmap=True)
stylized = whole_df.style.background_gradient(cmap=cm, axis=1)
stylized
# Out:
# <style  type="text/css" >
#     #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow0_col0 {
#             background-color:  #6e4071;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow0_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow0_col2 {
#             background-color:  #a5648d;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow0_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow0_col4 {
#             background-color:  #e1b1b4;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow1_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow1_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow1_col2 {
#             background-color:  #e7c1be;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow1_col3 {
#             background-color:  #452b54;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow1_col4 {
#             background-color:  #d79ea9;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow2_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow2_col1 {
#             background-color:  #b77495;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow2_col2 {
#             background-color:  #462b55;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow2_col3 {
#             background-color:  #b67395;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow2_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow3_col0 {
#             background-color:  #2e1f3f;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow3_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow3_col2 {
#             background-color:  #673c6d;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow3_col3 {
#             background-color:  #553361;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow3_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow4_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow4_col1 {
#             background-color:  #462b55;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow4_col2 {
#             background-color:  #854d7e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow4_col3 {
#             background-color:  #6f4172;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow4_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow5_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow5_col1 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow5_col2 {
#             background-color:  #724274;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow5_col3 {
#             background-color:  #452b54;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow5_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow6_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow6_col1 {
#             background-color:  #342245;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow6_col2 {
#             background-color:  #6e4071;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow6_col3 {
#             background-color:  #5b3665;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow6_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow7_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow7_col1 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow7_col2 {
#             background-color:  #724274;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow7_col3 {
#             background-color:  #432a53;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow7_col4 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow8_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow8_col1 {
#             background-color:  #814a7c;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow8_col2 {
#             background-color:  #e2b4b6;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow8_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow8_col4 {
#             background-color:  #312042;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow9_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow9_col1 {
#             background-color:  #3b264b;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow9_col2 {
#             background-color:  #6f4172;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow9_col3 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow9_col4 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow10_col0 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow10_col1 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow10_col2 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow10_col3 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow10_col4 {
#             background-color:  #b77495;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow11_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow11_col1 {
#             background-color:  #cc8da1;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow11_col2 {
#             background-color:  #4b2e59;
#             color:  #f1f1f1;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow11_col3 {
#             background-color:  #cc8da1;
#             color:  #000000;
#         }    #T_fc2043b0_c060_11ea_bb4e_98fa9be288bbrow11_col4 {
#             background-color:  #edd1cb;
#             color:  #0

# %% [markdown]
# Mean row wise rank (the lower the better):

# %%
whole_df.apply(lambda x: x.rank(ascending=False), axis=1).mean().sort_values()
# Out:
# SimAndEmbNormalized    1.861111
# SimAndEmb              2.055556
# OnlySimNormalized      3.055556
# OnlySim                3.736111
# OnlyEmb                4.291667
# dtype: float64

# %% [markdown]
# Interestingly normalization seems to be beneficial here

# %% [markdown]
# The Friedman test is designed to check if there is a significant difference in the rank sums

# %%
res = statistical_test(whole_df)
res
# Out:
# There is a significant difference in the rank sums:  1.8923043825176619e-26
#                      SimAndEmb  SimAndEmbNormalized   OnlySim  \
# SimAndEmb            -1.000000                0.900  0.001000
# SimAndEmbNormalized   0.900000               -1.000  0.001000
# OnlySim               0.001000                0.001 -1.000000
# OnlySimNormalized     0.001393                0.001  0.073738
# OnlyEmb               0.001000                0.001  0.216481
#
#                      OnlySimNormalized   OnlyEmb
# SimAndEmb                     0.001393  0.001000
# SimAndEmbNormalized           0.001000  0.001000
# OnlySim                       0.073738  0.216481
# OnlySimNormalized            -1.000000  0.001000
# OnlyEmb                       0.001000 -1.000000

# %% [markdown]
# Again the advantage of using similarities AND embeddings is clear here, which again is probably due to the missing CSV and Movie datasets.

# %% [markdown]
# # Analysis of Classifier Performance (on SimAndEmb)
# Similarly we analyze the different performance of the classifiers

# %%
whole_df = get_expanded_df(df,"vector_name","SimAndEmb",["embed_model","model_name","dataset"])
stylized = stylize(whole_df)
stylized
# Out:
# <style  type="text/css" >
#     #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col1 {
#             background-color:  #2e1f3f;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col2 {
#             background-color:  #382449;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col3 {
#             background-color:  #3d274e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col4 {
#             background-color:  #382449;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col5 {
#             background-color:  #39254a;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col6 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col7 {
#             background-color:  #3d274e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow0_col8 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col0 {
#             background-color:  #482c57;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col1 {
#             background-color:  #593564;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col2 {
#             background-color:  #5e3767;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col3 {
#             background-color:  #583463;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col4 {
#             background-color:  #5b3665;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col5 {
#             background-color:  #593564;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col6 {
#             background-color:  #ab6990;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col7 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow1_col8 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col1 {
#             background-color:  #794678;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col2 {
#             background-color:  #6b3e6f;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col3 {
#             background-color:  #5f3868;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col4 {
#             background-color:  #5e3767;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col5 {
#             background-color:  #553361;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col6 {
#             background-color:  #9d5d89;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col7 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow2_col8 {
#             background-color:  #553361;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col0 {
#             background-color:  #3d274e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col1 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col2 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col3 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col4 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col5 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col6 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col7 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow3_col8 {
#             background-color:  #3b264b;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col1 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col2 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col3 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col4 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col5 {
#             background-color:  #492d58;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col6 {
#             background-color:  #8e5383;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col7 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow4_col8 {
#             background-color:  #312042;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col0 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col1 {
#             background-color:  #5f3868;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col2 {
#             background-color:  #563362;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col3 {
#             background-color:  #50305d;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col4 {
#             background-color:  #4f305c;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col5 {
#             background-color:  #4d2f5b;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col6 {
#             background-color:  #774576;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col7 {
#             background-color:  #edd1cb;
#             color:  #000000;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow5_col8 {
#             background-color:  #2f2041;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col0 {
#             background-color:  #4c2e5a;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col1 {
#             background-color:  #673c6d;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col2 {
#             background-color:  #422952;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col3 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col4 {
#             background-color:  #352346;
#             color:  #f1f1f1;
#         }    #T_fc483b72_c060_11ea_bb4e_98fa9be288bbrow6_col5 {
#             background-color:  #2d1e3e;
#             color:  #f1f1f1;

# %%
whole_df.apply(lambda x: x.rank(ascending=False), axis=1).mean().sort_values()
# Out:
# random forest 500       2.764706
# random forest 200       3.470588
# MLP                     3.720588
# random forest 100       4.117647
# random forest 50        4.632353
# svc                     5.191176
# random forest 20        6.382353
# gaussian naive bayes    7.132353
# decision tree           7.588235
# dtype: float64

# %%
res = statistical_test(whole_df,features=False)
res
# Out:
# There is a significant difference in the rank sums:  2.819056165631006e-08
#                            svc  random forest 20  random forest 50  \
# svc                  -1.000000          0.662429          0.900000
# random forest 20      0.662429         -1.000000          0.172421
# random forest 50      0.900000          0.172421         -1.000000
# random forest 100     0.769909          0.018802          0.900000
# random forest 200     0.190233          0.001000          0.689302
# random forest 500     0.007955          0.001000          0.112008
# decision tree         0.009351          0.648994          0.001000
# gaussian naive bayes  0.083732          0.900000          0.005253
# MLP                   0.398811          0.002007          0.900000
#
#                       random forest 100  random forest 200  random forest 500  \
# svc                            0.769909           0.190233           0.007955
# random forest 20               0.018802           0.001000           0.001000
# random forest 50               0.900000           0.689302           0.112008
# random forest 100             -1.000000           0.900000           0.514642
# random forest 200              0.900000          -1.000000           0.900000
# random forest 500              0.514642           0.900000          -1.000000
# decision tree                  0.001000           0.001000           0.001000
# gaussian naive bayes           0.001000           0.001000           0.001000
# MLP                            0.900000           0.900000           0.877392
#
#                       decision tree  gaussian naive bayes       MLP
# svc                        0.009351              0.083732  0.398811
# random forest 20           0.648994              0.900000  0.002007
# random forest 50           0.001000              0.005253  0.900000
# random forest 100          0.001000              0.001000  0.900000
# random forest 200          0.001000              0.001000  0.900000
# random forest 500          0.001000              0.001000  0.877392
# decision tree             -1.000000              0.900000  0.001000
# gaussian naive bayes       0.900000             -1.000000  0.001000
# MLP                        0.001000              0.001000 -1.000000
